# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasariasolea/APRENDIZAJE-AUTOMATICO/blob/main/SEMANA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) ARCHIVO CSV

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f46a8e78-ac93-4cc2-9966-1f8f921dd99d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f46a8e78-ac93-4cc2-9966-1f8f921dd99d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

ventas = pd.read_csv("ventas (1).csv")
print(ventas.head())
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario
# 0         1  2026-01-10  Notebook         2             1200
# 1         2  2026-01-12     Mouse         5               25
# 2         3  2026-01-15   Teclado         3               45
# 3         4  2026-01-18   Monitor         1              300

# %% [markdown]
# 2. ARCHIVO JSON

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-424c272b-9fa9-439c-90a0-a0e65d8247ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-424c272b-9fa9-439c-90a0-a0e65d8247ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cargar archivo JSON
clientes = pd.read_json("clientes.json")

# Cantidad total de clientes
print(len(clientes))
# Out:
# 3

# %% [markdown]
# 3. ARCHIVO EXCEL

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8c22ab27-5bdf-4ba1-b02d-8f228d38cf0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c22ab27-5bdf-4ba1-b02d-8f228d38cf0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cargar archivo Excel
inventario = pd.read_excel("inventario.xlsx")

# Calcular promedio de stock
promedio_stock = inventario["stock"].mean()

print(promedio_stock)
# Out:
# 26.25
